# %%
import visuals.train_run as tr
import visuals.test_run as te
import visuals.load_runs as lr
import visuals.plot_selections as ps
import visuals.plot_training_reward as ptr
import visuals.plot_average_training as pat
import visuals.plot_test_reward as ptrw

from importlib import reload

reload(tr)
reload(te)
reload(lr)
reload(ps)
reload(ptr)
reload(pat)
reload(ptrw)

# %%
train_runs = lr.load_runs(is_train=True)

# %%
test_runs = lr.load_runs(is_train=False)

# %%
reload(ps)
ps.plot_selections(train_runs, velocity_label=True, align_velocitys=False, save_fig=True)

# %%
reload(ptr)
ptr.plot_adapted_rewards(train_runs, velocity_label=False, flattenings=1, save_fig=False)

# %%
reload(pat)
pat.plot_average_rewards(train_runs, flattenings=500, max_steps=60000, save_fig=False)

# %%
reload(ptrw)
ptrw.plot_test_reward(test_runs, flattenings=1, max_steps=500, save_fig=True)
