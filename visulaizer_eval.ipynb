# %%
import json
import os
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict

from src.checkpoint import RESULT_DIR, MODEL_DIR, STAT_DIR
from src.task_selectors.factory import get_selector_name, get_selector_old_name

stat_directory = RESULT_DIR + STAT_DIR

# %%
class Run():
    def __init__(self, filename: str):
        filename_splits = filename.split("_")
        self.selector = filename_splits[2]
        self.seed = int(filename_splits[4])
        self.iteration = int(filename_splits[6])
        self.test_env = int(filename_splits[8].split(".")[0])
        self.filename = filename
        
        # load and sort stats
        with open(f"{stat_directory}{filename}", "r") as f:
            self.stats: dict = json.load(f)
            self.stats_loc = self.stats.pop("loc")
        self.stats_generic: dict[str, list[float]] = {}
        self.stats_envs: dict[str, dict[str, list[float]]] = {}
        self.stats_envs_loc: dict[str, dict[str, list[int]]] = {}
        for k, v in self.stats.items():
            splits = str(k).split(" ")
            if splits[0] == "Env":
                stat = " ".join(splits[2:])
                env_index = int(splits[1])
                if stat not in self.stats_envs.keys():
                    self.stats_envs[stat] = {}
                    self.stats_envs_loc[stat] = {}
                self.stats_envs[stat][env_index] = v
                self.stats_envs_loc[stat][env_index] = self.stats_loc[k]
            else:
                self.stats_generic[k] = v
        for k, v in self.stats_envs.items():
            self.stats_envs[k] = OrderedDict(sorted(v.items()))
        
    def __str__(self):
        return f"{self.selector} with seed {self.seed} at iteration {self.iteration} of env {self.test_env}"
    
    def plot_stat(self, values, title, loc=None):
        def plot_line(values, label, loc=None):
            if loc is None:
                plt.plot(values, label=label)
            else:
                plt.plot(loc, values, label=label)
        plt.figure(figsize=(15,4))
        print(type(values))
        if type(values) == dict:
            for k, v in values.items():
                plot_line(v, k, loc[k])
        else:
            plot_line(values, title, loc)
        plt.title(title)
        plt.legend()
        plt.grid()
        plt.show()
    
    def plot_generic(self, flattenings: int = 0, skip=["policy_loss", "value_loss"], envs=[], selector=[]):
        if len(envs) > 0 and self.test_env not in envs:
            return
        if len(selector) > 0 and self.selector not in [get_selector_name(s) for s in selector]:
            return
        print(self)
        for k, v in self.stats_generic.items():
            if k in skip + ["lr"]:
                continue
            for _ in range(flattenings):
                v =  v[0:1] + [(v[i-1] + v[i] + v[i+1]) / 3 for i in range(1, len(v) - 1)] + v[-2:-1]
            self.plot_stat(v, k)
            
    def plot_envs(self, envs: list[int] = None, flattenings: int = 0):
        print(self)
        for k, stat in self.stats_envs.items():
            to_plot = {}
            to_plot_loc = {}
            for env, v in stat.items():
                if envs is None or env in envs:
                    for _ in range(flattenings):
                        v =  v[0:1] + [(v[i-1] + v[i] + v[i+1]) / 3 for i in range(1, len(v) - 1)] + v[-2:-1]
                    to_plot[env] = v
                    to_plot_loc[env] = self.stats_envs_loc[k][env]
            self.plot_stat(to_plot, k, to_plot_loc)

# %%
run_ids = [f for f in os.listdir(stat_directory) if f.split("_")[0] == "Eval"]
runs = [Run(name) for name in run_ids]
runs.sort(key=lambda r: (f"{r.selector}-{r.seed}", r.iteration))
for r in runs:
    print(r)
# Out:
# ContextSelector - Dissimilarity From Last with seed 1 at iteration 4000 of env 0
# ContextSelector - Dissimilarity From Last with seed 1 at iteration 4000 of env 1
# ContextSelector - Dissimilarity From Last with seed 1 at iteration 4000 of env 2
# ContextSelector - Dissimilarity From Last with seed 2 at iteration 4000 of env 0
# ContextSelector - Dissimilarity From Last with seed 2 at iteration 4000 of env 1
# ContextSelector - Dissimilarity From Last with seed 2 at iteration 4000 of env 2
# ContextSelector - Dissimilarity From Last with seed 3 at iteration 4000 of env 0
# ContextSelector - Dissimilarity From Last with seed 3 at iteration 4000 of env 1
# ContextSelector - Dissimilarity From Last with seed 3 at iteration 4000 of env 2
# ContextSelector - Generic Dissimilarity with seed 1 at iteration 4000 of env 0
# ContextSelector - Generic Dissimilarity with seed 1 at iteration 4000 of env 1
# ContextSelector - Generic Dissimilarity with seed 1 at iteration 4000 of env 2
# ...

# %%
def plot_average_reward(runs: list[Run], flattenings=10, color=None):
    returns = np.concat([np.array(run.stats_generic["episodic_return"]).reshape((1,-1)) for run in runs], axis=0)
    avg = np.average(returns, axis=0)[:500]
    for _ in range(flattenings):
        avg = np.concat([avg[0:1], np.array([(avg[i-1] + avg[i] + avg[i+1]) / 3 for i in range(1, len(avg) - 1)]), avg[-2:-1]])
    plt.plot(avg, label=runs[0].selector, color=color)
    #plt.title(f"Average episodic return - {runs[0].selector} - Env {runs[0].test_env}")
    #plt.show()

for e in range(3):
    title = f"Return after Test Adaptation - Velocity {[1.0, 4.0, 8.0][e]}"
    #plt.figure(figsize=(15,10))
    for i in range(14):
        # get a color for this selector except yellow which are hard to see
        color = plt.cm.tab20(i / 14)
        plot_average_reward([run for run in runs if run.selector == get_selector_old_name(i) and run.test_env == e], color=color)
    plt.title(title)
    plt.ylabel("Return")
    plt.xlabel("Episode")
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.savefig(f"plots/{title}.png", bbox_inches='tight', format="png")
    plt.show()

# %%
for r in runs:
    r.plot_generic(flattenings=100, skip=["policy_loss", "value_loss", "entropy"], envs=[2])
# Out:
# HardTaskSelector with seed 1 at iteration 1000 of env 2
# <class 'list'>
# HardTaskSelector with seed 1 at iteration 2000 of env 2
# <class 'list'>
# HardTaskSelector with seed 1 at iteration 3000 of env 2
# <class 'list'>
# HardTaskSelector with seed 1 at iteration 4000 of env 2
# <class 'list'>
# HardTaskSelector with seed 1 at iteration 5000 of env 2
# <class 'list'>
# HardTaskSelector with seed 1 at iteration 6000 of env 2
# <class 'list'>
# InsSelector - Dissimilarity From Last with seed 1 at iteration 1000 of env 2
# <class 'list'>
# InsSelector - Dissimilarity From Last with seed 1 at iteration 2000 of env 2
# <class 'list'>
# InsSelector - Dissimilarity From Last with seed 1 at iteration 3000 of env 2
# <class 'list'>
# InsSelector - Dissimilarity From Last with seed 1 at iteration 4000 of env 2
# <class 'list'>
# InsSelector - Dissimilarity From Last with seed 1 at iteration 5000 of env 2
# <class 'list'>
# ...

# %%
for r in runs:
    print(r)
    r.plot_envs(envs=[1, 4, 8, 6], flattenings=0)
# Out:
# HardTaskSelector with seed 1 at iteration 1000 of env 0
# HardTaskSelector with seed 1 at iteration 1000 of env 0
# HardTaskSelector with seed 1 at iteration 1000 of env 1
# HardTaskSelector with seed 1 at iteration 1000 of env 1
# HardTaskSelector with seed 1 at iteration 1000 of env 2
# HardTaskSelector with seed 1 at iteration 1000 of env 2
# HardTaskSelector with seed 1 at iteration 2000 of env 0
# HardTaskSelector with seed 1 at iteration 2000 of env 0
# HardTaskSelector with seed 1 at iteration 2000 of env 1
# HardTaskSelector with seed 1 at iteration 2000 of env 1
# HardTaskSelector with seed 1 at iteration 2000 of env 2
# HardTaskSelector with seed 1 at iteration 2000 of env 2
# HardTaskSelector with seed 1 at iteration 3000 of env 0
# HardTaskSelector with seed 1 at iteration 3000 of env 0
# HardTaskSelector with seed 1 at iteration 3000 of env 1
# HardTaskSelector with seed 1 at iteration 3000 of env 1
# HardTaskSelector with seed 1 at iteration 3000 of env 2
# ...
